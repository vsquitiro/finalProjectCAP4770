# %%
fileURL = 'https://cap4770dsprojectsum.s3.amazonaws.com/creditcard.csv'

# %%
import pandas as pd
import s3fs

df = pd.read_csv(fileURL)

# %%
from sklearn.preprocessing import MinMaxScaler

min_max = MinMaxScaler()

column_names = []
for name in df.columns:
  column_names.append(name)

x = df.values
x_scaled = min_max.fit_transform(x)
df = pd.DataFrame(x_scaled)
df.columns = column_names

# %%
df
# Out:
#             Time        V1        V2  ...       V28    Amount  Class
# 0       0.000000  0.935192  0.766490  ...  0.312697  0.005824    0.0
# 1       0.000000  0.978542  0.770067  ...  0.313423  0.000105    0.0
# 2       0.000006  0.935217  0.753118  ...  0.311911  0.014739    0.0
# 3       0.000006  0.941878  0.765304  ...  0.314371  0.004807    0.0
# 4       0.000012  0.938617  0.776520  ...  0.317490  0.002724    0.0
# ...          ...       ...       ...  ...       ...       ...    ...
# 284802  0.999965  0.756448  0.873531  ...  0.329840  0.000030    0.0
# 284803  0.999971  0.945845  0.766677  ...  0.312038  0.000965    0.0
# 284804  0.999977  0.990905  0.764080  ...  0.312585  0.002642    0.0
# 284805  0.999977  0.954209  0.772856  ...  0.315245  0.000389    0.0
# 284806  1.000000  0.949232  0.765256  ...  0.313401  0.008446    0.0
#
# [284807 rows x 31 columns]

# %%
from io import StringIO
import boto3

session = boto3.Session(
    aws_access_key_id='ASIAXJWRF3PZ7G5Q6HFZ',
    aws_secret_access_key='s4cH0F3h61zzs7hdYoqp5bbU47UHWaI27CSFyVKT',
    aws_session_token='',
    region_name='us-east-1'
)

bucket = 'cap4770dsprojectsum'
csv_buffer = StringIO()
df.to_csv(path_or_buf=csv_buffer, index=False)
s3_resource = session.resource('s3')
s3_resource.Object(bucket, 'pp_df.csv').put(Body=csv_buffer.getvalue())
# Out:
# {'ETag': '"ec4cba31e73c6f2c641f1713818b9f0d"',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '0',
#    'date': 'Mon, 03 Aug 2020 01:46:34 GMT',
#    'etag': '"ec4cba31e73c6f2c641f1713818b9f0d"',
#    'server': 'AmazonS3',
#    'x-amz-id-2': 'RPVglEakJZfma12foZCcLxTYRS4PajytdvtmtkqpiBuFrG6q4llsvZT5TnoQWPhr2Vdtju0em6Y=',
#    'x-amz-request-id': 'A691E899BACAE2A7'},
#   'HTTPStatusCode': 200,
#   'HostId': 'RPVglEakJZfma12foZCcLxTYRS4PajytdvtmtkqpiBuFrG6q4llsvZT5TnoQWPhr2Vdtju0em6Y=',
#   'RequestId': 'A691E899BACAE2A7',
#   'RetryAttempts': 0}}
